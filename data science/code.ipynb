# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# Add excel file
data = pd.read_excel('./Accident-Data-Collection.xlsx')

df = pd.DataFrame(data)

# %%
print(data.head())
# Out:
#        DATA  No of persons involved in accidents(X)  Death(Y)  X^2  Y^2  X*Y
# 0   JANUARY                                      69         6  414   36  414
# 1  FEBRUARY                                      63         3   89    9  189
# 2     MARCH                                      45         9  405   81  405
# 3     APRIL                                      72        12  864  144  864
# 4       MAY                                      80         3  240    9  240

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   DATA                                    13 non-null     object
#  1   No of persons involved in accidents(X)  13 non-null     int64
#  2   Death(Y)                                13 non-null     int64
#  3   X^2                                     13 non-null     int64
#  4   Y^2                                     13 non-null     int64
#  5   X*Y                                     13 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 756.0+ bytes
# None

# %%
# Create a scatter plot
plt.scatter(data['No of persons involved in accidents(X)'], data['Death(Y)'])
plt.title('Accidents vs Deaths')
plt.xlabel('No of persons involved in accidents')
plt.ylabel('Death')
plt.show()

# %%
# Create a linear regression model
model = LinearRegression()

# Prepare the data for modeling
X = data[['No of persons involved in accidents(X)']]
y = data['Death(Y)']

# Fit the model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Create a scatter plot
plt.scatter(data['No of persons involved in accidents(X)'], data['Death(Y)'], label='Data')
plt.title('Accidents vs Deaths')
plt.xlabel('No of persons involved in accidents')
plt.ylabel('Death')

# Plot the linear regression line
plt.plot(X, model.predict(X), color='red', label='Linear Regression')
plt.legend()
plt.show()

# %%
# Get the coefficients
intercept = model.intercept_
slope = model.coef_[0]

# Print the regression equation
print(f"Regression Equation: Y = {slope:.2f}X + {intercept:.2f}")
# Out:
# Regression Equation: Y = 0.08X + -0.00

# %%
# Create a scatter plot
plt.scatter(data['No of persons involved in accidents(X)'], data['Death(Y)'], label='Data')
plt.title('Accidents vs Deaths')
plt.xlabel('No of persons involved in accidents')
plt.ylabel('Death')

# Plot the linear regression line with the equation
plt.plot(X, model.predict(X), color='red', label=f'Linear Regression: Y = {slope:.2f}X + {intercept:.2f}')
plt.legend()
plt.show()

# %%
# Making a prediction using our model
persons_involved = 75
predicted_deaths = model.predict([[persons_involved]])
print(f"Predicted Deaths for {persons_involved} persons involved in accidents: {predicted_deaths[0]}")
# Out:
# Predicted Deaths for 75 persons involved in accidents: 5.9319259192858205
# c:\Users\SubZero\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
